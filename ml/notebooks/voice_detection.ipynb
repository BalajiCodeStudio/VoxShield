# %% [markdown]
# # VoxShield — AI Voice Deepfake Detection Playground
# Interactive notebook for testing the **RawTFNet** lightweight audio deepfake detector on live audio samples.

# %%
import os
import sys
import json
sys.path.insert(0, os.path.abspath('..'))

from ml.inference.detector import VoiceDetector

# 1. Initialize detector (loads model once)
detector = VoiceDetector()
detector.load_model()
print("RawTFNet model loaded successfully!")

# %%
# 2. Run inference on a sample audio file
result = detector.predict("../test_sample.wav")
print(json.dumps(result, indent=2))
